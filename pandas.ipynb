# %%
import pandas as pd
df = pd.read_csv('datas.csv')
df
# Out:
#    Sn    Name  Age    Address       Phone
# 0   1   Shyam   34  Kathmandu  9808667654
# 1   2    Hari   23  BHaktapur  9856556543
# 2   3   Sabin   46  Kathmandu  9867667543
# 3   4   Nabin   23  Bhaktapur  9867667543
# 4   5   Akash   45       Bara  9867667654
# 5   6  Nabina   56      Patan  9867667654

# %%
df.head(3)
# Out:
#    Sn   Name  Age    Address       Phone
# 0   1  Shyam   34  Kathmandu  9808667654
# 1   2   Hari   23  BHaktapur  9856556543
# 2   3  Sabin   46  Kathmandu  9867667543

# %%
df.tail(3)
# Out:
#    Sn    Name  Age    Address       Phone
# 3   4   Nabin   23  Bhaktapur  9867667543
# 4   5   Akash   45       Bara  9867667654
# 5   6  Nabina   56      Patan  9867667654

# %%
df.iloc[2:4]
# Out:
#    Sn   Name  Age    Address       Phone
# 2   3  Sabin   46  Kathmandu  9867667543
# 3   4  Nabin   23  Bhaktapur  9867667543

# %%
import pandas as pd
df = pd.read_csv('datas.csv',index_col = 'Sn')
df
# Out:
#       Name  Age    Address       Phone
# Sn
# 1    Shyam   34  Kathmandu  9808667654
# 2     Hari   23  BHaktapur  9856556543
# 3    Sabin   46  Kathmandu  9867667543
# 4    Nabin   23  Bhaktapur  9867667543
# 5    Akash   45       Bara  9867667654
# 6   Nabina   56      Patan  9867667654

# %%
import pandas as pd
df = pd.read_csv('datas.csv',index_col = 'Sn')
df.loc[2:5]
# Out:
#      Name  Age    Address       Phone
# Sn
# 2    Hari   23  BHaktapur  9856556543
# 3   Sabin   46  Kathmandu  9867667543
# 4   Nabin   23  Bhaktapur  9867667543
# 5   Akash   45       Bara  9867667654

# %%
import pandas as pd
df = pd.read_csv('datas.csv',index_col = 'Name')
df['Hari':'Akash']
# Out:
#        Sn  Age    Address       Phone
# Name
# Hari    2   23  BHaktapur  9856556543
# Sabin   3   46  Kathmandu  9867667543
# Nabin   4   23  Bhaktapur  9867667543
# Akash   5   45       Bara  9867667654

# %%
import pandas as pd
df = pd.read_csv('datas.csv',index_col = 'Sn')
df['Name']
# Out:
# Sn
# 1     Shyam
# 2      Hari
# 3     Sabin
# 4     Nabin
# 5     Akash
# 6    Nabina
# Name: Name, dtype: object

# %%
import pandas as pd
df = pd.read_csv('datas.csv',index_col = 'Sn')
df['Address'] == "Kathmandu"
# Out:
# Sn
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# Name: Address, dtype: bool

# %%
import pandas as pd
df = pd.read_csv('datas.csv',index_col = 'Sn')
df[df['Address'] == "Kathmandu"]
# Out:
#      Name  Age    Address       Phone
# Sn
# 1   Shyam   34  Kathmandu  9808667654
# 3   Sabin   46  Kathmandu  9867667543

# %%
import pandas as pd
df = pd.read_csv('datas.csv',index_col = 'Sn')
df[df['Age'] > 30]
# Out:
#       Name  Age    Address       Phone
# Sn
# 1    Shyam   34  Kathmandu  9808667654
# 3    Sabin   46  Kathmandu  9867667543
# 5    Akash   45       Bara  9867667654
# 6   Nabina   56      Patan  9867667654

# %%
import pandas as pd
df = pd.read_csv('datas.csv',index_col = 'Sn')
df[(df['Age'] > 30) & (df['Age']<40)]
# Out:
#      Name  Age    Address       Phone
# Sn
# 1   Shyam   34  Kathmandu  9808667654

# %%
import pandas as pd
df = pd.read_csv('datas.csv',index_col = 'Sn')
data = df[df['Age'] > 30]
data.to_csv('new_data.csv')

# %%
import pandas as pd
data = {'Name':['Ram','Shyam','Hari'],
       'Age':[23,45,32],
       'Address':['Kathmandu','Bhaktapur','Lalitpur']}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age    Address
# 0    Ram   23  Kathmandu
# 1  Shyam   45  Bhaktapur
# 2   Hari   32   Lalitpur

# %%
import csv
data = [['Name','Age','Address'],
        ['Ram',34,'Kathmandu'],
       ['Hari',45,'Bhaktapur'],
       ['Nabin',34,'lalitpur']]

f = open('list_data.csv','w')
x = csv.writer(f)
for i in data:
    x.writerow(i)
    
f.close()

# %%
import pandas as pd
df = pd.read_csv('list_data.csv')
df
# Out:
#     Name  Age    Address
# 0    Ram   34  Kathmandu
# 1   Hari   45  Bhaktapur
# 2  Nabin   34   lalitpur
